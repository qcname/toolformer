# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(BaseApI)
# Out:
# ---
#
# [source](https://github.com/qcname/toolformer/blob/main/toolformer/api.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### BaseApI
#
# >      BaseApI (name:str,
# >               prompt_template:langchain_core.prompts.prompt.PromptTemplate,
# >               sampling_threshold:float=0.2, filtering_threshold:float=0.2)
#
# *Initialize self.  See help(type(self)) for accurate signature.*
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | name | str |  | the name of API CALL |
# | prompt_template | PromptTemplate |  |  |
# | sampling_threshold | float | 0.2 |  |
# | filtering_threshold | float | 0.2 |  |

# %%
#| echo: false
#| output: asis
show_doc(CalcuatorAPI)
# Out:
# ---
#
# [source](https://github.com/qcname/toolformer/blob/main/toolformer/api.py#L29){target="_blank" style="float:right; font-size:smaller"}
#
# ### CalcuatorAPI
#
# >      CalcuatorAPI (name:str,
# >                    prompt_template:langchain_core.prompts.prompt.PromptTemplat
# >                    e, sampling_threshold:float=0.2,
# >                    filtering_threshold:float=0.2)
#
# *Initialize self.  See help(type(self)) for accurate signature.*
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | name | str |  | the name of API CALL |
# | prompt_template | PromptTemplate |  |  |
# | sampling_threshold | float | 0.2 |  |
# | filtering_threshold | float | 0.2 |  |

# %%
#| echo: false
#| output: asis
show_doc(WolframeAPI)
# Out:
# ---
#
# [source](https://github.com/qcname/toolformer/blob/main/toolformer/api.py#L37){target="_blank" style="float:right; font-size:smaller"}
#
# ### WolframeAPI
#
# >      WolframeAPI (*args, api_key:str, **kargs)
#
# *Initialize self.  See help(type(self)) for accurate signature.*
